# %%
import dask.array as da

# Create a sample Dask array
x = da.random.random((1000, 1000), chunks=(100, 100))

# Shuffle the array
x_shuffled = da.shuffle(x)

# Compute the result
x_shuffled = x_shuffled.compute()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 7
#       4 x = da.random.random((1000, 1000), chunks=(100, 100))
#       6 # Shuffle the array
# ----> 7 x_shuffled = da.shuffle(x)
#       9 # Compute the result
#      10 x_shuffled = x_shuffled.compute()
#
# AttributeError: module 'dask.array' has no attribute 'shuffle'
